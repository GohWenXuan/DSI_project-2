# %% [markdown]
# # PART 2 - Data Cleaning on Test Data

# %%
# Data Cleaning for Test Data

# %% [markdown]
# The test dataset will be cleaned using the same method for train dataset

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics as stats
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression, LassoCV, RidgeCV
from sklearn.preprocessing import OrdinalEncoder
from sklearn.metrics import r2_score
from sklearn.feature_selection import RFE

# Set graph to sns style
sns.set()

# %%
# Allow jupyter notebook to display all rows and columns
pd.set_option('display.max_columns', 999)
pd.set_option('display.max_rows', 999)

# %%
test = pd.read_csv('../data/test.csv')

# %%
print(test.shape)
test.head()
# Out:
# (878, 80)
#      Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0  2658  902301120          190        RM          69.0      9142   Pave
# 1  2718  905108090           90        RL           NaN      9662   Pave
# 2  2414  528218130           60        RL          58.0     17104   Pave
# 3  1989  902207150           30        RM          60.0      8520   Pave
# 4   625  535105100           20        RL           NaN      9500   Pave
#
#   Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0  Grvl       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 1   NaN       IR1          Lvl    AllPub     Inside        Gtl       Sawyer
# 2   NaN       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
# 3   NaN       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 4   NaN       IR1          Lvl    AllPub     Inside        Gtl        NAmes
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 0        Norm        Norm    2fmCon      2Story             6             8
# 1        Norm        Norm    Duplex      1Story             5             4
# 2        Norm        Norm      1Fam      2Story             7             5
# 3        Norm        Norm      1Fam      1Story             5             6
# 4        Norm        Norm      1Fam      1Story             6             5
#
#    Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd  \
# 0        1910            1950      Gable   CompShg      AsbShng      AsbShng
# 1        1977            1977      Gable   CompShg      Plywood      Plywood
# 2        2006            2006      Gable   CompShg      VinylSd      VinylSd
# 3        1923            2006      Gable   CompShg      Wd Sdng      Wd Sdng
# 4        1963            1963      Gable   CompShg      Plywood      Plywood
#
#   Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation Bsmt Qual  \
# 0         None           0.0         TA         Fa      Stone        Fa
# 1         None           0.0         TA         TA     CBlock        Gd
# 2         None           0.0         Gd         TA      PConc        Gd
# 3         None           0.0         Gd         TA     CBlock        TA
# 4      BrkFace         247.0         TA         TA     CBlock        Gd
#
#   Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  \
# 0        TA            No            Unf             0            Unf
# 1        TA            No            Unf             0            Unf
# 2        Gd            Av            GLQ           554            Unf
# 3        TA            No            Unf             0            Unf
# 4        TA            No            BLQ           609            Unf
#
#    BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating Heating QC Central Air  \
# 0             0         1020           1020    GasA         Gd           N
# 1             0         1967           1967    GasA         TA           Y
# 2             0          100            654    GasA         Ex           Y
# 3             0          968            968    GasA         TA           Y
# 4             0          785           1394    GasA         Gd           Y
#
#   Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  Gr Liv Area  \
# 0      FuseP         908        1020                0         1928
# 1      SBrkr        1967           0                0         1967
# 2      SBrkr         664         832                0         1496
# 3      SBrkr         968           0                0          968
# 4      SBrkr        1394           0                0         1394
#
#    Bsmt Full Bath  Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  \
# 0               0               0          2          0              4
# 1               0               0          2          0              6
# 2               1               0          2          1              3
# 3               0               0          1          0              2
# 4               1               0          1          1              3
#
#    Kitchen AbvGr Kitchen Qual  TotRms AbvGrd Functional  Fireplaces  \
# 0              2           Fa              9        Typ           0
# 1              2           TA             10        Typ           0
# 2              1           Gd              7        Typ           1
# 3              1           TA              5        Typ           0
# 4              1           TA              6        Typ           2
#
#   Fireplace Qu Garage Type  Garage Yr Blt Garage Finish  Garage Cars  \
# 0          NaN      Detchd         1910.0           Unf            1
# 1          NaN      Attchd         1977.0           Fin            2
# 2           Gd      Attchd         2006.0           RFn            2
# 3          NaN      Detchd         1935.0           Unf            2
# 4           Gd      Attchd         1963.0           RFn            2
#
#    Garage Area Garage Qual Garage Cond Paved Drive  Wood Deck SF  \
# 0          440          Po          Po           Y             0
# 1          580          TA          TA           Y           170
# 2          426          TA          TA           Y           100
# 3          480          Fa          TA           N             0
# 4          514          TA          TA           Y             0
#
#    Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area Pool QC  \
# 0             60             112           0             0          0     NaN
# 1              0               0           0             0          0     NaN
# 2             24               0           0             0          0     NaN
# 3              0             184           0             0          0     NaN
# 4             76               0           0           185          0     NaN
#
#   Fence Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type
# 0   NaN          NaN         0        4     2006       WD
# 1   NaN          NaN         0        8     2006       WD
# 2   NaN          NaN         0        9     2006       New
# 3   NaN          NaN         0        7     2007       WD
# 4   NaN          NaN         0        7     2009       WD

# %%
(test.isnull().sum()[test.isnull().sum() > 0] / test.shape[0]*100).sort_values(ascending=False)
# Out:
# Pool QC           99.544419
# Misc Feature      95.330296
# Alley             93.394077
# Fence             80.410023
# Fireplace Qu      48.063781
# Lot Frontage      18.223235
# Garage Yr Blt      5.125285
# Garage Finish      5.125285
# Garage Qual        5.125285
# Garage Cond        5.125285
# Garage Type        5.011390
# Bsmt Exposure      2.847380
# BsmtFin Type 1     2.847380
# BsmtFin Type 2     2.847380
# Bsmt Cond          2.847380
# Bsmt Qual          2.847380
# Mas Vnr Area       0.113895
# Mas Vnr Type       0.113895
# Electrical         0.113895
# dtype: float64

# %%
null_counts = test.isnull().sum()
null_counts[null_counts > 0]
# Out:
# Lot Frontage      160
# Alley             820
# Mas Vnr Type        1
# Mas Vnr Area        1
# Bsmt Qual          25
# Bsmt Cond          25
# Bsmt Exposure      25
# BsmtFin Type 1     25
# BsmtFin Type 2     25
# Electrical          1
# Fireplace Qu      422
# Garage Type        44
# Garage Yr Blt      45
# Garage Finish      45
# Garage Qual        45
# Garage Cond        45
# Pool QC           874
# Fence             706
# Misc Feature      837
# dtype: int64

# %% [markdown]
# **PID**

# %%
#drop column as it is a type of identifier
test.drop('PID',axis=1,inplace=True)

# %% [markdown]
# **Lot Frontage**

# %%
test['Lot Frontage'] = test.groupby(['MS SubClass','Lot Shape'])['Lot Frontage'].transform( lambda x: x.fillna(x.median()))
# Out:
# C:\Users\hoven\Anaconda3\envs\dsi-sg\lib\site-packages\numpy\lib\nanfunctions.py:1216: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\hoven\Anaconda3\envs\dsi-sg\lib\site-packages\numpy\lib\nanfunctions.py:1216: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)

# %%
test.loc[test['Lot Frontage'].isnull()]
# Out:
#       Id  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 187  193           75        RL           NaN      7793   Pave   NaN
# 204  757           70        RM           NaN      5775   Pave   NaN
#
#     Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 187       IR1          Bnk    AllPub     Corner        Gtl      BrkSide
# 204       IR2          Bnk    AllPub     Corner        Mod      OldTown
#
#     Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 187        Norm        Norm      1Fam      2.5Unf             7             7
# 204       Feedr        Norm      1Fam      2Story             6             7
#
#      Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st  \
# 187        1922            2005      Gable   CompShg      Wd Sdng
# 204        1915            2002      Gable   CompShg      Wd Sdng
#
#     Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation  \
# 187      Wd Sdng         None           0.0         TA         TA     BrkTil
# 204      Wd Sdng         None           0.0         TA         TA     BrkTil
#
#     Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1  \
# 187        Gd        TA            No            BLQ           474
# 204        TA        TA            No            Unf             0
#
#     BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating  \
# 187            Unf             0          634           1108    GasA
# 204            Unf             0          483            483    GasA
#
#     Heating QC Central Air Electrical  1st Flr SF  2nd Flr SF  \
# 187         TA           N      FuseA        1160         908
# 204         Ex           Y      SBrkr         741         686
#
#      Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  Bsmt Half Bath  Full Bath  \
# 187                0         2068               0               0          1
# 204                0         1427               0               0          1
#
#      Half Bath  Bedroom AbvGr  Kitchen AbvGr Kitchen Qual  TotRms AbvGrd  \
# 187          1              3              1           Gd              8
# 204          0              3              1           Gd              7
#
#     Functional  Fireplaces Fireplace Qu Garage Type  Garage Yr Blt  \
# 187        Typ           1           Gd      Detchd         1928.0
# 204        Typ           0          NaN      Attchd         1915.0
#
#     Garage Finish  Garage Cars  Garage Area Garage Qual Garage Cond  \
# 187           Unf            1          315          TA          TA
# 204           Unf            1          379          TA          TA
#
#     Paved Drive  Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  \
# 187           Y             0              0              60           0
# 204           Y             0             24             112           0
#
#      Screen Porch  Pool Area Pool QC Fence Misc Feature  Misc Val  Mo Sold  \
# 187             0          0     NaN   NaN          NaN         0        5
# 204             0          0     NaN   NaN          NaN         0        2
#
#      Yr Sold Sale Type
# 187     2010       WD
# 204     2009       WD

# %%
test['Lot Frontage'].fillna(test['Lot Frontage'].median(),inplace=True)

# %% [markdown]
# **Alley**

# %%
test['Alley'].unique()
# Out:
# array(['Grvl', nan, 'Pave'], dtype=object)

# %%
test['Alley'].fillna('Na',inplace=True)

# %% [markdown]
# **Mas Vnr Type**

# %%
test['Mas Vnr Type'].fillna('None',inplace=True)

# %% [markdown]
# **Mas Vnr Area**

# %%
test['Mas Vnr Area'].fillna(0.0,inplace=True)

# %%
test.loc[(test['Mas Vnr Area']>0) & (test['Mas Vnr Type']=='None')]
# Out:
#       Id  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 382  442           20        RL         102.0     13514   Pave    Na
# 862  404          160        RM          24.0      2368   Pave    Na
#
#     Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 382       IR1          Lvl    AllPub     Corner        Gtl      NridgHt
# 862       Reg          Lvl    AllPub     Inside        Gtl       BrDale
#
#     Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 382        Norm        Norm      1Fam      1Story             9             5
# 862        Norm        Norm    TwnhsE      2Story             5             6
#
#      Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st  \
# 382        2008            2008        Hip   CompShg      VinylSd
# 862        1970            1970      Gable   CompShg      HdBoard
#
#     Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation  \
# 382      VinylSd         None         285.0         Ex         TA      PConc
# 862      HdBoard         None         312.0         TA         TA     CBlock
#
#     Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1  \
# 382        Ex        TA            No            GLQ          1142
# 862        TA        TA            No            LwQ           765
#
#     BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating  \
# 382            Unf             0          632           1774    GasA
# 862            Unf             0            0            765    GasA
#
#     Heating QC Central Air Electrical  1st Flr SF  2nd Flr SF  \
# 382         Ex           Y      SBrkr        1808           0
# 862         TA           Y      SBrkr         765         600
#
#      Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  Bsmt Half Bath  Full Bath  \
# 382                0         1808               1               0          2
# 862                0         1365               0               0          1
#
#      Half Bath  Bedroom AbvGr  Kitchen AbvGr Kitchen Qual  TotRms AbvGrd  \
# 382          0              3              1           Ex              7
# 862          1              3              1           TA              7
#
#     Functional  Fireplaces Fireplace Qu Garage Type  Garage Yr Blt  \
# 382        Typ           1           Gd      Attchd         2008.0
# 862       Min1           0          NaN      Attchd         1970.0
#
#     Garage Finish  Garage Cars  Garage Area Garage Qual Garage Cond  \
# 382           Fin            3          850          TA          TA
# 862           Unf            2          440          TA          TA
#
#     Paved Drive  Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  \
# 382           Y           200             26               0           0
# 862           Y             0             36               0           0
#
#      Screen Porch  Pool Area Pool QC Fence Misc Feature  Misc Val  Mo Sold  \
# 382             0          0     NaN   NaN          NaN         0        3
# 862             0          0     NaN   NaN          NaN         0        5
#
#      Yr Sold Sale Type
# 382     2009       WD
# 862     2009       WD

# %%
test.iloc[[383],25] = test.iloc[[383],25].replace(285.0,0.0)

# %%
test.iloc[[863],25] = test.iloc[[863],25].replace(312.0,0.0)

# %% [markdown]
# **Bsmt Exposure**

# %%
test.loc[(test['Bsmt Exposure'].isnull()) & (test['Bsmt Qual'].notnull())]
# Out:
# Empty DataFrame
# Columns: [Id, MS SubClass, MS Zoning, Lot Frontage, Lot Area, Street, Alley, Lot Shape, Land Contour, Utilities, Lot Config, Land Slope, Neighborhood, Condition 1, Condition 2, Bldg Type, House Style, Overall Qual, Overall Cond, Year Built, Year Remod/Add, Roof Style, Roof Matl, Exterior 1st, Exterior 2nd, Mas Vnr Type, Mas Vnr Area, Exter Qual, Exter Cond, Foundation, Bsmt Qual, Bsmt Cond, Bsmt Exposure, BsmtFin Type 1, BsmtFin SF 1, BsmtFin Type 2, BsmtFin SF 2, Bsmt Unf SF, Total Bsmt SF, Heating, Heating QC, Central Air, Electrical, 1st Flr SF, 2nd Flr SF, Low Qual Fin SF, Gr Liv Area, Bsmt Full Bath, Bsmt Half Bath, Full Bath, Half Bath, Bedroom AbvGr, Kitchen AbvGr, Kitchen Qual, TotRms AbvGrd, Functional, Fireplaces, Fireplace Qu, Garage Type, Garage Yr Blt, Garage Finish, Garage Cars, Garage Area, Garage Qual, Garage Cond, Paved Drive, Wood Deck SF, Open Porch SF, Enclosed Porch, 3Ssn Porch, Screen Porch, Pool Area, Pool QC, Fence, Misc Feature, Misc Val, Mo Sold, Yr Sold, Sale Type]
# Index: []

# %%
test['Bsmt Exposure'].fillna('No',inplace=True)

# %%
test.replace({'Bsmt Exposure':{'Na':1, 'No':2, 'Mn':3, 'Av':4, 'Gd':5}},inplace=True)

# %% [markdown]
# **Bsmt Qual**

# %%
test['Bsmt Qual'].fillna('Na',inplace=True)

# %%
test.replace({'Bsmt Qual':{'Na':1,'Po':2,'Fa':3,'TA':4,'Gd':5,'Ex':6}},inplace=True)

# %% [markdown]
# **Bsmt Cond**

# %%
test['Bsmt Cond'].fillna('Na',inplace=True)

# %%
test['Bsmt Cond'].unique()
# Out:
# array(['TA', 'Gd', 'Na', 'Fa'], dtype=object)

# %%
test.replace({'Bsmt Cond':{'Na':1,'Po':2,'Fa':3,'TA':4,'Gd':5,'Ex':6}},inplace=True)

# %%
test['Bsmt Cond'] = test['Bsmt Cond'].astype(int)

# %% [markdown]
# **BsmtFin Type 1**

# %%
test['BsmtFin Type 1'].fillna('Na',inplace=True)

# %% [markdown]
# **BsmtFin Type 2**

# %%
test['BsmtFin Type 2'].fillna('Na',inplace=True)

# %% [markdown]
# **Electrical**

# %%
test.loc[test['Electrical'].isnull()]
# Out:
#        Id  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 634  1578           80        RL          73.0      9735   Pave    Na
#
#     Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 634       Reg          Lvl    AllPub     Inside        Gtl       Timber
#
#     Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 634        Norm        Norm      1Fam        SLvl             5             5
#
#      Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st  \
# 634        2006            2007      Gable   CompShg      VinylSd
#
#     Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation  \
# 634      VinylSd         None           0.0         TA         TA      PConc
#
#      Bsmt Qual  Bsmt Cond  Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1  \
# 634          5          4              2            Unf             0
#
#     BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating  \
# 634            Unf             0          384            384    GasA
#
#     Heating QC Central Air Electrical  1st Flr SF  2nd Flr SF  \
# 634         Gd           Y        NaN         754         640
#
#      Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  Bsmt Half Bath  Full Bath  \
# 634                0         1394               0               0          2
#
#      Half Bath  Bedroom AbvGr  Kitchen AbvGr Kitchen Qual  TotRms AbvGrd  \
# 634          1              3              1           Gd              7
#
#     Functional  Fireplaces Fireplace Qu Garage Type  Garage Yr Blt  \
# 634        Typ           0          NaN     BuiltIn         2007.0
#
#     Garage Finish  Garage Cars  Garage Area Garage Qual Garage Cond  \
# 634           Fin            2          400          TA          TA
#
#     Paved Drive  Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  \
# 634           Y           100              0               0           0
#
#      Screen Porch  Pool Area Pool QC Fence Misc Feature  Misc Val  Mo Sold  \
# 634             0          0     NaN   NaN          NaN         0        5
#
#      Yr Sold Sale Type
# 634     2008       WD

# %%
test['Electrical'].mode()
# Out:
# 0    SBrkr
# Name: Electrical, dtype: object

# %%
test['Electrical'].fillna('SBrkr',inplace=True)

# %% [markdown]
# **Fireplace Qu**

# %%
test['Fireplace Qu'].fillna('Na',inplace=True)

# %%
test.replace({'Fireplace Qu': {'Na':1, 'Po':2, 'Fa':3, 'TA':4, 'Gd':5, 'Ex':6}},inplace=True)

# %% [markdown]
# **Garage Type**

# %%
test.loc[(test['Garage Type'].notnull()) & (test['Garage Yr Blt'].isnull())]
# Out:
#        Id  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 764  1357           60        RM          57.0      8094   Pave  Grvl
#
#     Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 764       Reg          Lvl    AllPub     Inside        Gtl      OldTown
#
#     Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 764        Norm        Norm    2fmCon      2.5Unf             6             8
#
#      Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st  \
# 764        1910            1983      Gable   CompShg      Wd Sdng
#
#     Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation  \
# 764      Wd Sdng         None           0.0         TA         TA      PConc
#
#      Bsmt Qual  Bsmt Cond  Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1  \
# 764          4          4              3            Rec           196
#
#     BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating  \
# 764            Unf             0         1046           1242    GasA
#
#     Heating QC Central Air Electrical  1st Flr SF  2nd Flr SF  \
# 764         Gd           Y      SBrkr        1242         742
#
#      Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  Bsmt Half Bath  Full Bath  \
# 764                0         1984               0               0          2
#
#      Half Bath  Bedroom AbvGr  Kitchen AbvGr Kitchen Qual  TotRms AbvGrd  \
# 764          0              5              1           TA              8
#
#     Functional  Fireplaces  Fireplace Qu Garage Type  Garage Yr Blt  \
# 764        Typ           0             1      Detchd            NaN
#
#     Garage Finish  Garage Cars  Garage Area Garage Qual Garage Cond  \
# 764           NaN            1          360         NaN         NaN
#
#     Paved Drive  Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  \
# 764           Y            64              0             180           0
#
#      Screen Porch  Pool Area Pool QC  Fence Misc Feature  Misc Val  Mo Sold  \
# 764             0          0     NaN  MnPrv         Shed      1000        9
#
#      Yr Sold Sale Type
# 764     2008       WD

# %%
test.groupby(['MS SubClass','Garage Type'])[['Garage Yr Blt','Garage Finish','Garage Qual','Garage Cond']].apply(stats.mode)
# Out:
# MS SubClass  Garage Type
# 20           2Types         Garage Yr Blt
#              Attchd         Garage Yr Blt
#              Basment        Garage Yr Blt
#              CarPort        Garage Yr Blt
#              Detchd         Garage Yr Blt
# 30           2Types         Garage Yr Blt
#              Attchd         Garage Yr Blt
#              Detchd         Garage Yr Blt
# 40           Attchd         Garage Yr Blt
# 45           Detchd         Garage Yr Blt
# 50           Attchd         Garage Yr Blt
#              Basment        Garage Yr Blt
#              BuiltIn        Garage Yr Blt
#              Detchd         Garage Yr Blt
# 60           Attchd         Garage Yr Blt
#              BuiltIn        Garage Yr Blt
#              Detchd         Garage Yr Blt
# 70           Attchd         Garage Yr Blt
#              Basment        Garage Yr Blt
#              BuiltIn        Garage Yr Blt
#              Detchd         Garage Yr Blt
# 75           Attchd         Garage Yr Blt
#              Detchd         Garage Yr Blt
# 80           Attchd         Garage Yr Blt
#              Basment        Garage Yr Blt
#              BuiltIn        Garage Yr Blt
#              Detchd         Garage Yr Blt
# 85           Attchd         Garage Yr Blt
#              Detchd         Garage Yr Blt
# 90           Attchd         Garage Yr Blt
#              BuiltIn        Garage Yr Blt
#              CarPort        Garage Yr Blt
#              Detchd         Garage Yr Blt
# 120          Attchd         Garage Yr Blt
#              Detchd         Garage Yr Blt
# 160          Attchd         Garage Yr Blt
#              BuiltIn        Garage Yr Blt
#              CarPort        Garage Yr Blt
#              Detchd         Garage Yr Blt
# 180          Attchd         Garage Yr Blt
#              Basment        Garage Yr Blt
# 190          Attchd         Garage Yr Blt
#              CarPort        Garage Yr Blt
#              Detchd         Garage Yr Blt
# dtype: object

# %%
test.iloc[[765],[58]] = test.iloc[[765],[58]].fillna(1947.0)

# %%
test.iloc[[765],[59]] = test.iloc[[765],[59]].fillna('Unf')

# %%
test.iloc[[765],[62]] = test.iloc[[765],[62]].fillna('TA')

# %%
test.iloc[[765],[63]] = test.iloc[[765],[63]].fillna('TA')

# %%
test['Garage Type'].fillna('Na',inplace=True)

# %% [markdown]
# **Garage Yr Blt**

# %%
test.loc[(test['Garage Yr Blt'].isnull()) & (test['Garage Type'].notnull())].shape
# Out:
# (45, 79)

# %%
test['Garage Yr Blt'].fillna(0.0,inplace=True)

# %% [markdown]
# **Garage Finish**

# %%
test['Garage Finish'].fillna('Na',inplace=True)

# %% [markdown]
# **Garage Qual**

# %%
test['Garage Qual'].fillna('Na',inplace=True)

# %%
test.replace({'Garage Qual': {'Na':1, 'Po':2, 'Fa':3, 'TA':4, 'Gd':5, 'Ex':6}},inplace=True)

# %%
test['Garage Qual'] = test['Garage Qual'].astype(int)

# %% [markdown]
# **Garage Cond**

# %%
test['Garage Cond'].fillna('Na',inplace=True)

# %%
test.replace({'Garage Cond': {'Na':1, 'Po':2, 'Fa':3, 'TA':4, 'Gd':5, 'Ex':6}},inplace=True)

# %% [markdown]
# **Pool QC**

# %%
test.loc[(test['Pool QC'].isnull()) & (test['Pool Area'] != 0)]
# Out:
# Empty DataFrame
# Columns: [Id, MS SubClass, MS Zoning, Lot Frontage, Lot Area, Street, Alley, Lot Shape, Land Contour, Utilities, Lot Config, Land Slope, Neighborhood, Condition 1, Condition 2, Bldg Type, House Style, Overall Qual, Overall Cond, Year Built, Year Remod/Add, Roof Style, Roof Matl, Exterior 1st, Exterior 2nd, Mas Vnr Type, Mas Vnr Area, Exter Qual, Exter Cond, Foundation, Bsmt Qual, Bsmt Cond, Bsmt Exposure, BsmtFin Type 1, BsmtFin SF 1, BsmtFin Type 2, BsmtFin SF 2, Bsmt Unf SF, Total Bsmt SF, Heating, Heating QC, Central Air, Electrical, 1st Flr SF, 2nd Flr SF, Low Qual Fin SF, Gr Liv Area, Bsmt Full Bath, Bsmt Half Bath, Full Bath, Half Bath, Bedroom AbvGr, Kitchen AbvGr, Kitchen Qual, TotRms AbvGrd, Functional, Fireplaces, Fireplace Qu, Garage Type, Garage Yr Blt, Garage Finish, Garage Cars, Garage Area, Garage Qual, Garage Cond, Paved Drive, Wood Deck SF, Open Porch SF, Enclosed Porch, 3Ssn Porch, Screen Porch, Pool Area, Pool QC, Fence, Misc Feature, Misc Val, Mo Sold, Yr Sold, Sale Type]
# Index: []

# %%
test['Pool QC'].fillna('Na',inplace=True)

# %%
test.replace({'Pool QC': {'Na':1, 'Fa':2, 'TA':3, 'Gd':4,'Ex':5}},inplace=True)

# %% [markdown]
# **Fence**

# %%
test['Fence'].fillna('Na',inplace=True)

# %% [markdown]
# **Misc Feature**

# %%
test.drop(['Misc Feature'], axis=1, inplace=True)

# %% [markdown]
# **Exter Qual**

# %%
test['Exter Qual'].unique()
# Out:
# array(['TA', 'Gd', 'Fa', 'Ex'], dtype=object)

# %%
test.replace({'Exter Qual': {'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5}},inplace=True)

# %% [markdown]
# **Exter Cond**

# %%
test.replace({'Exter Cond': {'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5}},inplace=True)

# %% [markdown]
# **Heating QC**

# %%
test.replace({'Heating QC': {'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5}},inplace=True)

# %% [markdown]
# **Kitchen Qual**

# %%
test['Kitchen Qual'].unique()
# Out:
# array(['Fa', 'TA', 'Gd', 'Ex', 'Po'], dtype=object)

# %%
test.replace({'Kitchen Qual': {'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5}},inplace=True)

# %% [markdown]
# **MS Zoning**

# %%
test.replace({'MS Zoning': {'C (all)':'C','A (agr)':'A','I (all)':'I'}},inplace=True)

# %%
test.dtypes
# Out:
# Id                   int64
# MS SubClass          int64
# MS Zoning           object
# Lot Frontage       float64
# Lot Area             int64
# Street              object
# Alley               object
# Lot Shape           object
# Land Contour        object
# Utilities           object
# Lot Config          object
# Land Slope          object
# Neighborhood        object
# Condition 1         object
# Condition 2         object
# Bldg Type           object
# House Style         object
# Overall Qual         int64
# Overall Cond         int64
# Year Built           int64
# Year Remod/Add       int64
# Roof Style          object
# Roof Matl           object
# Exterior 1st        object
# Exterior 2nd        object
# Mas Vnr Type        object
# Mas Vnr Area       float64
# Exter Qual           int64
# Exter Cond           int64
# Foundation          object
# Bsmt Qual            int64
# Bsmt Cond            int32
# Bsmt Exposure        int64
# BsmtFin Type 1      object
# BsmtFin SF 1         int64
# BsmtFin Type 2      object
# BsmtFin SF 2         int64
# Bsmt Unf SF          int64
# Total Bsmt SF        int64
# Heating             object
# Heating QC           int64
# Central Air         object
# Electrical          object
# 1st Flr SF           int64
# 2nd Flr SF           int64
# Low Qual Fin SF      int64
# Gr Liv Area          int64
# Bsmt Full Bath       int64
# Bsmt Half Bath       int64
# Full Bath            int64
# Half Bath            int64
# Bedroom AbvGr        int64
# Kitchen AbvGr        int64
# Kitchen Qual         int64
# TotRms AbvGrd        int64
# Functional          object
# Fireplaces           int64
# Fireplace Qu         int64
# Garage Type         object
# Garage Yr Blt      float64
# Garage Finish       object
# Garage Cars          int64
# Garage Area          int64
# Garage Qual          int32
# Garage Cond          int64
# Paved Drive         object
# Wood Deck SF         int64
# Open Porch SF        int64
# Enclosed Porch       int64
# 3Ssn Porch           int64
# Screen Porch         int64
# Pool Area            int64
# Pool QC              int64
# Fence               object
# Misc Val             int64
# Mo Sold              int64
# Yr Sold              int64
# Sale Type           object
# dtype: object

# %% [markdown]
# ## Verify Null values are filled

# %%
test.isnull().sum()
# Out:
# Id                 0
# MS SubClass        0
# MS Zoning          0
# Lot Frontage       0
# Lot Area           0
# Street             0
# Alley              0
# Lot Shape          0
# Land Contour       0
# Utilities          0
# Lot Config         0
# Land Slope         0
# Neighborhood       0
# Condition 1        0
# Condition 2        0
# Bldg Type          0
# House Style        0
# Overall Qual       0
# Overall Cond       0
# Year Built         0
# Year Remod/Add     0
# Roof Style         0
# Roof Matl          0
# Exterior 1st       0
# Exterior 2nd       0
# Mas Vnr Type       0
# Mas Vnr Area       0
# Exter Qual         0
# Exter Cond         0
# Foundation         0
# Bsmt Qual          0
# Bsmt Cond          0
# Bsmt Exposure      0
# BsmtFin Type 1     0
# BsmtFin SF 1       0
# BsmtFin Type 2     0
# BsmtFin SF 2       0
# Bsmt Unf SF        0
# Total Bsmt SF      0
# Heating            0
# Heating QC         0
# Central Air        0
# Electrical         0
# 1st Flr SF         0
# 2nd Flr SF         0
# Low Qual Fin SF    0
# Gr Liv Area        0
# Bsmt Full Bath     0
# Bsmt Half Bath     0
# Full Bath          0
# Half Bath          0
# Bedroom AbvGr      0
# Kitchen AbvGr      0
# Kitchen Qual       0
# TotRms AbvGrd      0
# Functional         0
# Fireplaces         0
# Fireplace Qu       0
# Garage Type        0
# Garage Yr Blt      0
# Garage Finish      0
# Garage Cars        0
# Garage Area        0
# Garage Qual        0
# Garage Cond        0
# Paved Drive        0
# Wood Deck SF       0
# Open Porch SF      0
# Enclosed Porch     0
# 3Ssn Porch         0
# Screen Porch       0
# Pool Area          0
# Pool QC            0
# Fence              0
# Misc Val           0
# Mo Sold            0
# Yr Sold            0
# Sale Type          0
# dtype: int64

# %% [markdown]
# ## Export data

# %%
# export file
test.to_csv('../data/test_cleaned.csv',index=False)
